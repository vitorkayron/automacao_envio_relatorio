# %%
import pyautogui
import pyperclip
import time
import pandas as pd

pyautogui.PAUSE = 2

# Passo 1: Entrar no link do google drive
pyautogui.hotkey('ctrl', 't')
pyperclip.copy('https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')
time.sleep(3)

# Passo 2: Navegar até o local do relatório (entrar na pasta exportar) 
pyautogui.click(x=340, y=293, clicks=2)
time.sleep(4)

# Passo 3: Fazer download do relatório
pyautogui.click(x=393, y=375)
pyautogui.click(x=1158, y=193)
pyautogui.click(x=902, y=622)
time.sleep(5)

# Passo 4: Calcular os indicadores
tabela = pd.read_excel(r"C:\Users\danie\Downloads\Vendas - Dez.xlsx")

faturamento = tabela['Valor Final'].sum()
quantidade = tabela['Quantidade'].sum()
time.sleep(2)
# Passo 5: Entrar no email

pyautogui.hotkey('ctrl', 't')
pyperclip.copy('https://mail.google.com/mail/u/0/#inbox')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')
time.sleep(5)

# Passo 6: Enviar por email o resultado
pyautogui.click(x=90, y=189)
pyautogui.write('pythonimpressionador+diretoria@gmail.com')
pyautogui.press('tab') #seleciona o email
pyautogui.press('tab') #pula para o campo de assunto
pyperclip.copy('Relatório de vendas')
pyautogui.hotkey('ctrl', 'v') #escrever o assunto
pyautogui.press('tab') #pula para o campo da mensagem

texto = f'''
Prezados, bom dia

O faturamento de ontem foi de: {faturamento}
A quantidade de produtos foi de:{quantidade}
    
Abs, Vitor
'''
time.sleep(2)
pyperclip.copy(texto)
pyautogui.hotkey('ctrl', 'v')
pyautogui.hotkey('ctrl', 'enter')
